# %% [markdown]
# <a href="https://colab.research.google.com/github/banteamlak1888/Fundamentals-for-AI/blob/main/Hello_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello AI")
# Out:
# Hello AI

# %%
print("What about think people say to you")
print("            👇")
print("I sied that I don'tn care what about people sie to me!")
# Out:
# What about think people say to you
#             👇
# I sied that I don'tn care what about people sie to me!

# %%
print("Hello, AI.")
print("-> Me: People's what think about to you? ")
print("-> AI: I don't care what people say to me.")
print("-> Me: AI said that I don't care people side about me.")
print("-> Motivoter: አንተ ድንቅ ነህ! እኛ ድንቅነን ! ሁላችንም እንችላለን! ")
print("፟-> AI: Please don't make me laugh 😁😁😁😁.")
# Out:
# Hello, AI.
# -> Me: People's what think about to you?
# -> AI: I don't care what people say to me.
# -> Me: AI said that I don't care people side about me.
# -> Motivoter: አንተ ድንቅ ነህ! እኛ ድንቅነን ! ሁላችንም እንችላለን!
# ፟-> AI: Please don't make me laugh 😁😁😁😁.
